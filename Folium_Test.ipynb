# %%
#Collin Reinking
#collin.reinking@berkeley.edu

import folium
# %matplotlib inline
import pandas as pd
import re
import os
import branca.colormap as cm
import re
import numpy as np
#import matplotlib as mpl
#import matplotlib.pyplot as plt
#from matplotlib import colors
#from scipy import stats

# %%
data = pd.read_csv('df_test.csv')
data = pd.DataFrame(data, columns = ['LATT','LONGT','COMP','FIELD','DAY','MONTH','DEPTH']) #[:50]  <-this kind of slice is useful for developing a map
data.head()
#data['TEXT'] = data['FIELD'] 
data['TEXT'] = data['COMP'] +' ('+data['FIELD']+')'

# %%
#create a map
this_map = folium.Map(prefer_canvas=True)

def plotDot(point):
    '''input: series that contains a numeric named latitude and a numeric named longitude
    this function creates a CircleMarker and adds it to your this_map'''
    folium.CircleMarker(location=[point.LATT, point.LONGT],
                        radius=5,
                        fill=True,
                        popup=point.TEXT,
                        color='blue',
                        weight=2).add_to(this_map)

#use df.apply(,axis=1) to iterate through every row in your dataframe
data.apply(plotDot, axis = 1)


#Set the zoom to the maximum possible
this_map.fit_bounds(this_map.get_bounds())

#Save the map to an HTML file
#this_map.save(os.path.join('c:\\','1Remote','simple_dot_plot.html'))

this_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from folium import FeatureGroup, LayerControl, Map, Marker
from folium.plugins import HeatMap

#create a map
this_map = folium.Map(location=[55, -110])

def plotDot(point):
    '''input: series that contains a numeric named latitude and a numeric named longitude
    this function creates a CircleMarker and adds it to your this_map'''
    folium.Map(location=[55, -110]).add_to(this_map)

#use df.apply(,axis=1) to iterate through every row in your dataframe
#data.apply(plotDot, axis = 1)
hmdata = [ data.LATT.values, data.LONGT.values ]

hm = HeatMap(hmdata)
this_map.add_child(hm)
#Set the zoom to the maximum possible
this_map.fit_bounds(this_map.get_bounds())

#Save the map to an HTML file
#this_map.save(os.path.join('c:\\','1Remote','simple_dot_plot.html'))

this_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#create a map
this_map = folium.Map(prefer_canvas=True)

#create a color map
color_var = 'TEMP' #what variable will determine the color
cmap = cm.LinearColormap(['#f1eef6','#d0d1e6','#a6bddb','#74a9cf','#3690c0','#0570b0','#034e7b'],
                         vmin=data[color_var].quantile(0.01), vmax=data[color_var].quantile(1),
                         caption = 'DEPTH (m)')

#Add the color map legend to your map
this_map.add_child(cmap)

def plotDot(point):
    '''input: series that contains a numeric named latitude and a numeric named longitude
    this function creates a CircleMarker and adds it to your this_map'''
    folium.CircleMarker(location=[point.LATT, point.LONGT],
                        fill_color=cmap(point[color_var]),
                        color=cmap(point[color_var]),
                        radius=3,
                        popup=point.TEXT,
                        weight=3).add_to(this_map)

#use df.apply(,axis=1) to iterate through every row in your dataframe
data.apply(plotDot, axis = 1)

#Set the zoom to the maximum possible
this_map.fit_bounds(this_map.get_bounds())

#Save the map to an HTML file
this_map.save(os.path.join('c:\\','1Remote','Q2-3_WCR2018.html'))


this_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for d in data.LATT:
    print(d)
    #[data['LATT']]
# Out:
# 55.54974552
# 55.288476
# 54.20533669
# 50.63913399
# 50.61016543
# 51.62112839
# 54.84545487
# 54.84545487
# 54.21991393
# 54.21991393
# 54.21991393
# 54.21991393
# 54.21991393
# 54.21991393
# 52.62711719
# 52.88851595
# 54.8891902
# 54.8891902
# 51.27206868
# 55.5285552
# 51.27939076
# 55.79804312
# 54.51103678
# 54.8891902
# 51.62112839
# 52.19535976
# 52.19537153
# 52.19537153
# 52.19537153
# 55.52062311
# 55.52062311
# 52.18812687
# 55.45501397
# 55.45501251
# 52.18811686
# 52.19537153
# 54.19083257
# 49.89651078
# 54.32026797
# 54.24036777
# 54.24036777
# 54.24036777
# 54.24036777
# 53.86939267
# 53.86939267
# 53.86939267
# 53.86939267
# 53.86939267
# 53.86939267
# 53.86939267
# 53.75294231
# 53.75294231
# 53.75294231
# 53.75294231
# 53.75294231
# 53.75294231
# 52.33352556
# 54.39380083
# 54.39380083
# 54.39380083
# 54.56208524
# 50.33320631
# 50.33320631
# 50.54438905
# 54.13993193
# 54.13993193
# 54.13993193
# 54.08174217
# 54.08174217
# 54.08184731
# 54.08184731
# ...

# %%
data.LATT for d in data.LATT
# Out:
#   File "<ipython-input-106-bfd3f4867d06>", line 1
#     data.LATT for d in data.LATT
#                 ^
# SyntaxError: invalid syntax

# %%
data.MONTH.values
# Out:
# array([7, 7, 7, ..., 4, 4, 4], dtype=int64)

# %%
data['TEXT']
# Out:
# 0                            CENOVUS FCCL LTD. (MCMURRAY)
# 1                    SECURE ENERGY SERVICES INC. (BELLOY)
# 2                     TANGLE CREEK ENERGY LTD. (DUNVEGAN)
# 3                           TAQA NORTH LTD. (GLAUCONITIC)
# 4                           TAQA NORTH LTD. (GLAUCONITIC)
# 5                         HURON RESOURCES CORP. (WABAMUN)
# 6                     HAMMERHEAD RESOURCES INC. (CADOTTE)
# 7                     HAMMERHEAD RESOURCES INC. (CADOTTE)
# 8                     ATHABASCA OIL CORPORATION (MONTNEY)
# 9                     ATHABASCA OIL CORPORATION (MONTNEY)
# 10                    ATHABASCA OIL CORPORATION (MONTNEY)
# 11                    ATHABASCA OIL CORPORATION (MONTNEY)
# 12                    ATHABASCA OIL CORPORATION (MONTNEY)
# 13                    ATHABASCA OIL CORPORATION (MONTNEY)
# 14      PEYTO EXPLORATION & DEVELOPMENT CORP. (NOTIKEWIN)
# 15                          TORC OIL & GAS LTD. (CARDIUM)
# ...

# %%
data['TEST'] = data['MONTH'].astype(str) + data['DAY'].astype(str)
data['TEST'] = data['TEST'].astype(int)
data.TEST
# Out:
# 0       73
# 1       73
# 2       73
# 3       73
# 4       73
# 5       73
# 6       73
# 7       73
# 8       73
# 9       73
# 10      73
# 11      73
# 12      73
# 13      73
# 14      73
# 15      73
# 16      74
# 17      74
# 18      74
# 19      74
# 20      74
# 21      74
# 22      74
# 23      74
# 24      74
# 25      74
# 26      74
# 27      74
# 28      74
# 29      74
#       ...
# 661    413
# 662    413
# 663    413
# 664    417
# 665    417
# 666    417
# 667    417
# 668    417
# 669    418
# 670    418
# 671    418
# 672    419
# 673    419
# 674    419
# 675    419
# 676    419
# 677    419
# 678    419
# 679    419
# 680    419
# 681    419
# 682    420
# 683    420
# 684    424
# 685    424
# 686    424
# 687    424
# 688    424
# 689    424
# 690    425
# Name: TEST, Length: 691, dtype: int32

# %%
import re

# %%
temp=[]
for d in data['DEPTH']:
    temp.append(float(d[:-1]))

# %%
test= re.sub("[mM]",'',)
# Out:
#   File "<ipython-input-279-e55d8b2d5073>", line 1
#     test= re.sub("[mM]",'',for d in data['DEPTH'])
#                              ^
# SyntaxError: invalid syntax

# %%
temp
# Out:
# [1470.0,
#  2313.0,
#  3400.0,
#  4360.0,
#  4200.0,
#  4669.0,
#  1962.0,
#  5500.0,
#  4250.0,
#  3760.4,
#  5500.0,
#  5538.5,
#  583.0,
#  2760.0,
#  1810.0,
#  3390.0,
#  1650.0,
#  2050.0,
#  2700.0,
#  1650.0,
#  2700.0,
#  2700.0,
#  1375.0,
#  7000.0,
#  1891.0,
#  384.0,
#  577.7,
#  520.0,
#  764.0,
#  1400.0,
#  614.0,
#  5070.0,
#  3013.0,
#  508.0,
#  5650.0,
#  6780.0,
#  6660.0,
#  1965.0,
#  6300.0,
#  5200.0,
#  2053.0,
#  3360.0,
#  2756.0,
#  3000.0,
#  5600.0,
#  5150.0,
#  4100.0,
#  4900.0,
#  5554.8,
#  1872.0,
#  1060.0,
#  4530.0,
#  436.0,
#  434.0,
#  442.0,
#  433.0,
#  433.0,
#  428.0,
#  5685.0,
#  5728.0,
#  2690.0,
#  3635.0,
#  4184.0,
#  1940.0,
#  3681.0,
#  3600.0,
#  2381.0,
#  5181.1,
#  5925.0,
#  2000.0,
#  2205.0,
#  5100.0,
#  3450.0,
#  4450.0,
#  6530.0,
#  7414.0,
#  6610.0,
#  4671.9,
#  1820.0,
#  3500.0,
#  3100.0,
#  3500.0,
#  4235.0,
#  3900.0,
#  3400.0,
#  3750.0,
#  1600.0,
#  2007.0,
#  4095.0,
#  3190.0,
#  1580.0,
#  541.0,
# ...

# %%
pdtemp = pd.DataFrame({'TEMP':temp})

# %%
data['TEMP']=pdtemp['TEMP']
