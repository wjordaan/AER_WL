# %%
#Collin Reinking
#collin.reinking@berkeley.edu

import folium
# %matplotlib inline
import pandas as pd
import re
import os
import branca.colormap as cm
import re
import numpy as np
#import matplotlib as mpl
#import matplotlib.pyplot as plt
#from matplotlib import colors
#from scipy import stats

# %%
data = pd.read_csv('df_test.csv')
data = pd.DataFrame(data, columns = ['LATT','LONGT','COMP','FIELD','DAY','MONTH','DEPTH']) #[:50]  <-this kind of slice is useful for developing a map
data.head()
#data['TEXT'] = data['FIELD'] 
data['TEXT'] = data['COMP'] +' ('+data['FIELD']+')'

# %%
data = data[data['COMP']=='GRIZZLY RESOURCES LTD.']

# %%
#create a map
this_map = folium.Map(prefer_canvas=True)

def plotDot(point):
    '''input: series that contains a numeric named latitude and a numeric named longitude
    this function creates a CircleMarker and adds it to your this_map'''
    folium.CircleMarker(location=[point.LATT, point.LONGT],
                        radius=5,
                        fill=True,
                        popup=point.TEXT,
                        color='blue',
                        weight=2).add_to(this_map)

#use df.apply(,axis=1) to iterate through every row in your dataframe
data.apply(plotDot, axis = 1)


#Set the zoom to the maximum possible
this_map.fit_bounds(this_map.get_bounds())

#Save the map to an HTML file
#this_map.save(os.path.join('c:\\','1Remote','simple_dot_plot.html'))

this_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from folium import FeatureGroup, LayerControl, Map, Marker
from folium.plugins import HeatMap

#create a map
this_map = folium.Map(location=[55, -110])

def plotDot(point):
    '''input: series that contains a numeric named latitude and a numeric named longitude
    this function creates a CircleMarker and adds it to your this_map'''
    folium.Map(location=[55, -110]).add_to(this_map)

#use df.apply(,axis=1) to iterate through every row in your dataframe
#data.apply(plotDot, axis = 1)
hmdata = [ data.LATT.values, data.LONGT.values ]

hm = HeatMap(hmdata)
this_map.add_child(hm)
#Set the zoom to the maximum possible
this_map.fit_bounds(this_map.get_bounds())

#Save the map to an HTML file
#this_map.save(os.path.join('c:\\','1Remote','simple_dot_plot.html'))

this_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#create a map
this_map = folium.Map(prefer_canvas=True)

#create a color map
color_var = 'MONTH' #what variable will determine the color
cmap = cm.LinearColormap(['#f1eef6','#d0d1e6','#a6bddb','#74a9cf','#3690c0','#0570b0','#034e7b'],
                         vmin=data[color_var].quantile(0.01), vmax=data[color_var].quantile(1),
                         caption = 'DEPTH (m)')

#Add the color map legend to your map
this_map.add_child(cmap)

def plotDot(point):
    '''input: series that contains a numeric named latitude and a numeric named longitude
    this function creates a CircleMarker and adds it to your this_map'''
    folium.CircleMarker(location=[point.LATT, point.LONGT],
                        fill_color=cmap(point[color_var]),
                        color=cmap(point[color_var]),
                        radius=6,
                        popup=point.TEXT,
                        weight=3).add_to(this_map)
    print(1,[point.LATT, point.LONGT])

#use df.apply(,axis=1) to iterate through every row in your dataframe
data.apply(plotDot, axis = 1)

#Set the zoom to the maximum possible
this_map.fit_bounds(this_map.get_bounds())

#Save the map to an HTML file
this_map.save(os.path.join('c:\\','1Remote','Q2-3_WCR2018.html'))


this_map
# Out:
# 1 [55.79804312, -119.1148362]
# 1 [55.79081604, -119.11483770000001]
# 1 [55.78357281, -119.0889629]
# 1 [55.8052765, -119.0500858]
# 1 [55.80530298, -119.11484229999999]
# 1 [55.79726318, -119.0500909]
# 1 [55.79080031, -119.088958]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 55.65860173
# 55.65860173
# 55.65860173
# 55.65860173
# 55.65860173
# 55.65860173
# 55.65860173
# 55.65860173
# 55.65860173
# 55.65860173
# 55.65860173
# 55.65860173
# 55.65860173
# 55.65860173
# 55.65860173
# 55.65860173
# 55.65860173
# 55.65860173
# 55.65860173
# 55.65860173
# 55.65860173
# 53.68847138
# 53.68847138
# 53.68847138
# 54.20530365
# 54.20530365
# 54.50390993
# 54.54742557
# 54.54742557
# 54.54742557
# 54.51110055
# 52.26315982
# 52.26315982
# 52.26315982
# 55.63061159
# 55.63061159
# 52.83806846
# 52.83806846
# 55.78357281
# 55.78357281
# 55.78357281
# 55.79080031
# 55.79080031
# 54.75108653
# 55.79080031
# 55.79080031
# 55.6585924
# 55.6585924
# 55.6585924
# 55.6585924
# 55.6585924
# 55.6585924
# 55.6585924
# 55.66605378
# 55.66605378
# 55.66605378
# 54.51111601
# 54.51111601
# 54.51111601
# 54.51834378
# 54.51111601
# 54.51111601
# 54.51111601
# 54.51834378
# 54.51834378
# 54.51111601
# 54.51834378
# 55.23104131
# 55.23104131
# 54.21278582
# 51.92751428
# 52.3407275
# 52.71463178
# 52.71463178
# 52.65622896
# 52.65622896
# 52.65622896
# 54.75108945
# 53.368018500000005
# 53.368018500000005
# 53.368018500000005
# 52.53014434
# 55.58600476
# 52.75097206
# 51.94148625
# 55.6585924
# 55.6585924
# 55.6585924
# 55.6585924
# 55.6585924
# 55.6585924
# 55.6585924
# 55.6585924
# 55.6585924
# 55.66605378
# 55.513541599999996
# 52.43548316
# 50.07860784
# 53.69601622
# 51.76690693
# 51.76690693
# 52.53012532
# 54.51834378
# 56.07486944
# 56.07486944
# 55.21639076
# 55.21639076
# 55.21639076
# 55.21639076
# 52.24836287
# 52.5810083
# 54.44573768
# 54.80880168
# 56.09652535
# 50.25328198
# 51.94148599
# 54.44573768
# 52.15900560000001
# 52.15900560000001
# 54.44573768
# 54.44573768
# 53.76743008
# 52.18087199
# 52.18810532
# 53.80392478
# 55.53504922
# 55.53504922
# 55.53504922
# 55.53504922
# 55.53504922
# 55.53504922
# 54.47303124
# 54.47303124
# 54.47303124
# 51.96999579
# 51.96999579
# 54.48204106
# 54.48204106
# 54.13270785
# 54.13270785
# 53.78266711
# 53.78266711
# 55.15102434
# 55.15102434
# 55.15102434
# 55.15102434
# 55.15102434
# 55.15102434
# 55.15102434
# 57.24492094
# 57.24492094
# 57.24492094
# 57.24492094
# 57.24492094
# 57.24492094
# 57.24492094
# 57.24492094
# 57.24492094
# 57.24492094
# 53.28116012
# 53.803905500000006
# 53.803905500000006
# 52.64116525

# %%
data.LATT for d in data.LATT
# Out:
#   File "<ipython-input-106-bfd3f4867d06>", line 1
#     data.LATT for d in data.LATT
#                 ^
# SyntaxError: invalid syntax

# %%
data.MONTH.values
# Out:
# array([7, 7, 7, ..., 4, 4, 4], dtype=int64)

# %%
data['TEXT']
# Out:
# 14     GRIZZLY RESOURCES LTD. (CREEK)
# 49     GRIZZLY RESOURCES LTD. (CREEK)
# 151    GRIZZLY RESOURCES LTD. (CREEK)
# 335    GRIZZLY RESOURCES LTD. (CREEK)
# 562    GRIZZLY RESOURCES LTD. (CREEK)
# 598    GRIZZLY RESOURCES LTD. (CREEK)
# 649    GRIZZLY RESOURCES LTD. (CREEK)
# Name: TEXT, dtype: object

# %%
data['TEST'] = data['MONTH'].astype(str) + data['DAY'].astype(str)
data['TEST'] = data['TEST'].astype(int)
data.TEST
# Out:
# 0       73
# 1       73
# 2       73
# 3       73
# 4       73
# 5       73
# 6       73
# 7       73
# 8       73
# 9       73
# 10      73
# 11      73
# 12      73
# 13      73
# 14      73
# 15      73
# 16      74
# 17      74
# 18      74
# 19      74
# 20      74
# 21      74
# 22      74
# 23      74
# 24      74
# 25      74
# 26      74
# 27      74
# 28      74
# 29      74
#       ...
# 661    413
# 662    413
# 663    413
# 664    417
# 665    417
# 666    417
# 667    417
# 668    417
# 669    418
# 670    418
# 671    418
# 672    419
# 673    419
# 674    419
# 675    419
# 676    419
# 677    419
# 678    419
# 679    419
# 680    419
# 681    419
# 682    420
# 683    420
# 684    424
# 685    424
# 686    424
# 687    424
# 688    424
# 689    424
# 690    425
# Name: TEST, Length: 691, dtype: int32

# %%
import re

# %%
temp=[]
for d in data['DEPTH']:
    temp.append(float(d[:-1]))

# %%
test= re.sub("[mM]",'',)
# Out:
#   File "<ipython-input-279-e55d8b2d5073>", line 1
#     test= re.sub("[mM]",'',for d in data['DEPTH'])
#                              ^
# SyntaxError: invalid syntax

# %%
temp
# Out:
# [1810.0, 1872.0, 2435.1, 1613.0, 1774.0, 1649.0, 1349.0]

# %%
pdtemp = pd.DataFrame({'TEMP':temp})

# %%
data['TD']=pdtemp['TEMP']

# %%
data
# Out:
#           LATT       LONGT                    COMP  FIELD  DAY  MONTH  \
# 14   55.798043 -119.114836  GRIZZLY RESOURCES LTD.  CREEK    3      7
# 49   55.790816 -119.114838  GRIZZLY RESOURCES LTD.  CREEK    6      7
# 151  55.783573 -119.088963  GRIZZLY RESOURCES LTD.  CREEK   24      7
# 335  55.805276 -119.050086  GRIZZLY RESOURCES LTD.  CREEK    4      6
# 562  55.805303 -119.114842  GRIZZLY RESOURCES LTD.  CREEK   17      5
# 598  55.797263 -119.050091  GRIZZLY RESOURCES LTD.  CREEK   28      5
# 649  55.790800 -119.088958  GRIZZLY RESOURCES LTD.  CREEK   11      4
#
#        DEPTH                            TEXT  TEMP  TD
# 14   1810.0M  GRIZZLY RESOURCES LTD. (CREEK)   NaN NaN
# 49   1872.0M  GRIZZLY RESOURCES LTD. (CREEK)   NaN NaN
# 151  2435.1M  GRIZZLY RESOURCES LTD. (CREEK)   NaN NaN
# 335  1613.0M  GRIZZLY RESOURCES LTD. (CREEK)   NaN NaN
# 562  1774.0M  GRIZZLY RESOURCES LTD. (CREEK)   NaN NaN
# 598  1649.0M  GRIZZLY RESOURCES LTD. (CREEK)   NaN NaN
# 649  1349.0M  GRIZZLY RESOURCES LTD. (CREEK)   NaN NaN
